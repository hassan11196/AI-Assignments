# %%
import json # for preprocessing
import numpy as np # for data manipulation
import pandas as pd # for data manipulation
from sklearn.model_selection import train_test_split # for data split
from sklearn.preprocessing import LabelEncoder,StandardScaler, MinMaxScaler, MaxAbsScaler # for preprocessing
from sklearn.ensemble import RandomForestClassifier # for Training Model
from sklearn.ensemble import ExtraTreesClassifier # For training model

from sklearn.metrics import accuracy_score
import joblib # for saving trained model

# %%
training_set = pd.read_excel('./parktraining.xlsx',header=None)
test_set = pd.read_excel('./parktesting.xlsx',header=None)

# %%
X = training_set.iloc[:,:-1]
y = training_set.iloc[:,-1]

X_test = test_set.iloc[:,:-1]
y_test = test_set.iloc[:,-1]

# %%
X.head()
# Out:
#         0        1        2        3        4        5        6        7   \
# 0  187.733  202.324  173.015  0.00316  0.00002  0.00168  0.00182  0.00504
# 1  186.163  197.724  177.584  0.00298  0.00002  0.00165  0.00175  0.00496
# 2  184.055  196.537  166.977  0.00258  0.00001  0.00134  0.00147  0.00403
# 3  237.226  247.326  225.227  0.00298  0.00001  0.00169  0.00182  0.00507
# 4  241.404  248.834  232.483  0.00281  0.00001  0.00157  0.00173  0.00470
#
#         8      9   ...       12       13       14      15        16        17  \
# 0  0.01663  0.151  ...  0.01366  0.02488  0.00265  26.310  0.396793  0.758324
# 1  0.01495  0.135  ...  0.01233  0.02321  0.00231  26.822  0.326480  0.765623
# 2  0.01463  0.132  ...  0.01234  0.02226  0.00257  26.453  0.306443  0.759203
# 3  0.01752  0.164  ...  0.01133  0.03104  0.00740  22.736  0.305062  0.654172
# 4  0.01760  0.154  ...  0.01251  0.03017  0.00675  23.145  0.457702  0.634267
#
#          18        19        20        21
# 0 -6.006647  0.266892  2.382544  0.160691
# 1 -6.647379  0.201095  2.374073  0.130554
# 2 -7.044105  0.063412  2.361532  0.115730
# 3 -7.310550  0.098648  2.416838  0.095032
# 4 -6.793547  0.158266  2.256699  0.117399
#
# [5 rows x 22 columns]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    0
# Name: 22, dtype: int64

# %%
# Feature Scaling
for column in X:
    X[column] = X[column].map(lambda x: (x - min(X[column])) / (max(X[column]) - min(X[column])))

# %%
X.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.560636  0.204495  0.619129  0.047014  0.051383  0.048170  0.048232
# 1  0.551105  0.195105  0.645434  0.041296  0.051383  0.046724  0.044480
# 2  0.538307  0.192682  0.584367  0.028590  0.011858  0.031792  0.029475
# 3  0.861104  0.296357  0.919727  0.041296  0.011858  0.048651  0.048232
# 4  0.886468  0.299436  0.961501  0.035896  0.011858  0.042871  0.043408
#
#          7         8         9   ...        12        13        14        15  \
# 0  0.048162  0.058883  0.050330  ...  0.042801  0.072153  0.001088  0.831619
# 1  0.046878  0.043450  0.037129  ...  0.032544  0.061433  0.000000  0.855447
# 2  0.031947  0.040511  0.034653  ...  0.032621  0.055334  0.000832  0.838274
# 3  0.048643  0.067059  0.061056  ...  0.024832  0.111696  0.016287  0.665286
# 4  0.042703  0.067793  0.052805  ...  0.033932  0.106111  0.014208  0.684321
#
#          16        17        18        19        20        21
# 0  0.327180  0.744862  0.297269  0.586688  0.323634  0.191963
# 1  0.163120  0.774403  0.171238  0.438570  0.319188  0.125550
# 2  0.116368  0.748420  0.093202  0.128626  0.312605  0.092883
# 3  0.113145  0.323334  0.040792  0.207947  0.341634  0.047271
# 4  0.469298  0.242774  0.142486  0.342156  0.257581  0.096561
#
# [5 rows x 22 columns]

# %%
model = GaussianNB()
model = model.fit(X, y)

model2 = RandomForestClassifier()
model2 = model2.fit(X,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
X_test.head()
# Out:
#         0        1        2        3        4        5        6        7   \
# 0  119.992  157.302   74.997  0.00784  0.00007  0.00370  0.00554  0.01109
# 1  122.400  148.650  113.819  0.00968  0.00008  0.00465  0.00696  0.01394
# 2  116.682  131.111  111.555  0.01050  0.00009  0.00544  0.00781  0.01633
# 3  116.676  137.871  111.366  0.00997  0.00009  0.00502  0.00698  0.01505
# 4  116.014  141.781  110.655  0.01284  0.00011  0.00655  0.00908  0.01966
#
#         8      9   ...       12       13       14      15        16        17  \
# 0  0.04374  0.426  ...  0.02971  0.06545  0.02211  21.033  0.414783  0.815285
# 1  0.06134  0.626  ...  0.04368  0.09403  0.01929  19.085  0.458359  0.819521
# 2  0.05233  0.482  ...  0.03590  0.08270  0.01309  20.651  0.429895  0.825288
# 3  0.05492  0.517  ...  0.03772  0.08771  0.01353  20.644  0.434969  0.819235
# 4  0.06425  0.584  ...  0.04465  0.10470  0.01767  19.649  0.417356  0.823484
#
#          18        19        20        21
# 0 -4.813031  0.266482  2.301442  0.284654
# 1 -4.075192  0.335590  2.486855  0.368674
# 2 -4.443179  0.311173  2.342259  0.332634
# 3 -4.117501  0.334147  2.405554  0.368975
# 4 -3.747787  0.234513  2.332180  0.410335
#
# [5 rows x 22 columns]

# %%
for column in X_test:
    X_test[column] = X_test[column].map(lambda x: (x - min(X_test[column])) / (max(X_test[column]) - min(X_test[column])))

# %%
class GaussianNB():

# %%
pred = model.predict(X_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.8974358974358975

# %%
pred2 = model2.predict(X_test)
accuracy_score(y_test, pred2)
# Out:
# 0.9487179487179487
